# %%
# import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# read in the data
df = pd.read_csv(r'C:\Users\adria\OneDrive\Documents\Adrian\Developer\Portfolio Project - Alex The Analyst\Project 4 - Correlation in Python\movies.csv')

# %%
# preview the data
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
# test for missing data
for col in df.columns:
    missing_pc = np.mean(df[col].isna())
    print('{} : {}%'.format(col, missing_pc))
# Out:
# name : 0.0%
# rating : 0.010041731872717789%
# genre : 0.0%
# year : 0.0%
# released : 0.0002608242044861763%
# score : 0.0003912363067292645%
# votes : 0.0003912363067292645%
# director : 0.0%
# writer : 0.0003912363067292645%
# star : 0.00013041210224308815%
# country : 0.0003912363067292645%
# budget : 0.2831246739697444%
# gross : 0.02464788732394366%
# company : 0.002217005738132499%
# runtime : 0.0005216484089723526%

# %%
# drop rows with missing data
df_cleaned = df.copy().dropna()

# %%
# test for missing data again
for col in df_cleaned.columns:
    missing_pc = np.mean(df_cleaned[col].isna())
    print('{} : {}%'.format(col, missing_pc))
# Out:
# name : 0.0%
# rating : 0.0%
# genre : 0.0%
# year : 0.0%
# released : 0.0%
# score : 0.0%
# votes : 0.0%
# director : 0.0%
# writer : 0.0%
# star : 0.0%
# country : 0.0%
# budget : 0.0%
# gross : 0.0%
# company : 0.0%
# runtime : 0.0%

# %%
# data types for columns
df_cleaned.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
# change data type of budget, gross earnings and votes to integer
df_cleaned['budget'] = df_cleaned['budget'].astype('int64')
df_cleaned['gross'] = df_cleaned['gross'].astype('int64')
df_cleaned['votes'] = df_cleaned['votes'].astype('int64')

# %%
df_cleaned.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score    votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
# year in the data does not always match the release year according to the release date
# add a column to df with the year according to the release date
df_cleaned['year_correct'] = df_cleaned['released'].str.split(' ').str[2]
df_cleaned.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score    votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
df_cleaned.sort_values('gross', inplace=False, ascending=False).head()
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#                                released  score    votes       director  \
# 5445  December 18, 2009 (United States)    7.8  1100000  James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000  Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  1100000  James Cameron
# 6663  December 18, 2015 (United States)    7.8   876000    J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000  Anthony Russo
#
#                   writer               star        country     budget  \
# ...

# %%
# drop any duplicates
df_unique = df_cleaned['company'].drop_duplicates()

# %%
df_unique
# Out:
# 0                                            Warner Bros.
# 1                                       Columbia Pictures
# 2                                               Lucasfilm
# 3                                      Paramount Pictures
# 4                                          Orion Pictures
# 6                                      Universal Pictures
# 7                            Chartoff-Winkler Productions
# 8                                          Dovemead Films
# 9                                          United Artists
# 10                                    The Malpaso Company
# 11                                           C.A.T. Films
# 14                                      Filmways Pictures
# 15                                        Rastar Pictures
# 17                                              IPC Films
# 18                                  AVCO Embassy Pictures
# 20                             Lorimar Film Entertainment
# ...

# %%
# Prediction 1: gross revenue has a high correlation to budget
# Prediction 2: gross revenue has a high correlation to company

# %%
# scatter plot of budget vs gross revenue
plt.style.use('ggplot')
x=df_cleaned['budget']
y=df_cleaned['gross']
plt.title('Budget vs. Gross Earnings')
plt.xlabel('Budget')
plt.ylabel('Gross Earnings')
plt.scatter(x, y)
z = np.polyfit(x, y, 1)
p = np.poly1d(z)
plt.plot(x, p(x), color="blue", linewidth=2, linestyle="--", label="Linear Trendline")
plt.show()

# %%
print(f"Linear Trendline: y = {p[1]:.6f}x + {p[0]:.6f}")
# Out:
# Linear Trendline: y = 3.335072x + -16863517.225032

# %%
# plot budget vs gross revenue using seaborn
sns.regplot(x='budget',y='gross',data=df_cleaned, scatter_kws={'color':'red'}, line_kws={'color':'blue'})
plt.show()

# %%
df_cleaned.corr(method='pearson', numeric_only=True) #pearson, kendall, spearman
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.056386  0.206021  0.327722  0.274321  0.075077
# score    0.056386  1.000000  0.474256  0.072001  0.222556  0.414068
# votes    0.206021  0.474256  1.000000  0.439675  0.614751  0.352303
# budget   0.327722  0.072001  0.439675  1.000000  0.740247  0.318695
# gross    0.274321  0.222556  0.614751  0.740247  1.000000  0.275796
# runtime  0.075077  0.414068  0.352303  0.318695  0.275796  1.000000

# %%
# high correlation between gross revenue and budget
# prediction 1 therefore holds

# %%
# visualize the correlation matrix
correlation_matrix = df_cleaned.corr(method='pearson', numeric_only=True)
sns.heatmap(correlation_matrix, annot=True)
plt.title('Correlation matrix for numeric features')
plt.xlabel('Movie features')
plt.ylabel('Movie features')
plt.show()

# %%
df_numerized = df_cleaned.copy()
for col in df_numerized.columns:
    if(df_numerized[col].dtype == 'object'):
        df_numerized[col] = df_numerized[col].astype('category')
        df_numerized[col] = df_numerized[col].cat.codes

df_numerized
# Out:
#       name  rating  genre  year  released  score    votes  director  writer  \
# 0     4692       6      6  1980      1304    8.4   927000      1795    2832
# 1     3929       6      1  1980      1127    5.8    65000      1578    1158
# 2     3641       4      0  1980      1359    8.7  1200000       757    1818
# 3      204       4      4  1980      1127    7.7   221000       889    1413
# 4      732       6      4  1980      1170    7.3   108000       719     351
# ...    ...     ...    ...   ...       ...    ...      ...       ...     ...
# 7648   415       6      0  2020       904    6.6   140000        16    2390
# 7649  3556       4      0  2020       713    6.5   102000       852    2309
# 7650  1153       4      1  2020       904    5.6    53000      1809    2827
# 7651  3978       4      1  2020       758    6.8    42000       294    2091
# 7652  4090       3      0  2020       370    6.8     3700       746    1184
#
# ...

# %%
# visualize the correlation matrix
correlation_matrix = df_numerized.corr(method='pearson', numeric_only=True)
sns.heatmap(correlation_matrix, annot=True)
plt.title('Correlation matrix for numeric features')
plt.xlabel('Movie features')
plt.ylabel('Movie features')
plt.show()

# %%
df_numerized.corr()
# Out:
#                   name    rating     genre      year  released     score  \
# name          1.000000 -0.029234  0.010996  0.025542 -0.006152  0.014450
# rating       -0.029234  1.000000  0.147796  0.019499  0.018083  0.065983
# genre         0.010996  0.147796  1.000000 -0.073167  0.022142  0.035106
# year          0.025542  0.019499 -0.073167  1.000000 -0.001740  0.056386
# released     -0.006152  0.018083  0.022142 -0.001740  1.000000  0.045874
# score         0.014450  0.065983  0.035106  0.056386  0.045874  1.000000
# votes         0.012615  0.006031 -0.135990  0.206021  0.028833  0.474256
# director      0.015246  0.014656 -0.008553 -0.038354  0.002308  0.005413
# writer        0.012880 -0.003149  0.017578 -0.025908  0.008072  0.012843
# star         -0.006882  0.009196  0.003341 -0.032157  0.015706  0.007296
# country      -0.025490  0.008230 -0.009164 -0.066748 -0.017228 -0.043051
# budget        0.023392 -0.203946 -0.368523  0.327722  0.019952  0.072001
# ...

# %%
corr_matrix = df_numerized.corr()
corr_pairs = corr_matrix.unstack()

# %%
sorted_pairs = corr_pairs.sort_values(ascending=False)
sorted_pairs[(sorted_pairs)>0.5]
# Out:
# name          name            1.000000
# rating        rating          1.000000
# runtime       runtime         1.000000
# company       company         1.000000
# gross         gross           1.000000
# budget        budget          1.000000
# country       country         1.000000
# star          star            1.000000
# writer        writer          1.000000
# director      director        1.000000
# votes         votes           1.000000
# score         score           1.000000
# released      released        1.000000
# year          year            1.000000
# genre         genre           1.000000
# year_correct  year_correct    1.000000
#               year            0.994821
# year          year_correct    0.994821
# budget        gross           0.740247
# gross         budget          0.740247
#               votes           0.614751
# votes         gross           0.614751
# dtype: float64

# %%
# votes and budget have the highest correlations to gross revenue
# prediction 2 therefore does not hold.
